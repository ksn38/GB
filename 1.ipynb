# %% [markdown]
# Задача 1
#
# Имеется колода в 52 карты. Найти число возможностей вытянуть из неё 4 карты так, чтобы среди них был хотя бы один туз.

# %%
Число возможностей вытянуть 1 туз:
    4С1 = 4!/1!*(4-1)! = 4
Число возможностей вытянуть остальный 3 карты без тузов в колоде:
    48С3 = 48!/3!*(48-3)! = 17296
Число возможностей вытянуть 4 карты с одним тузом:
    4С1*48С3 = 69184
    
Число возможностей вытянуть 2 туза:
    4С2 = 4!/2!*(4-2)! = 6
Число возможностей вытянуть остальный 2 карты без тузов в колоде:
    48С2 = 48!/2!*(48-2)! = 1128
Число возможностей вытянуть 4 карты с одним тузом:
    4С2*48С2 = 6768

Число возможностей вытянуть 3 туза:
    4С3 = 4!/3!*(4-3)! = 4
Число возможностей вытянуть остальную 1 карту без тузов в колоде:
    48С1 = 48!/1!*(48-1)! = 48
Число возможностей вытянуть 4 карты с одним тузом:
    4С3*48С1 = 192
    
Число возможностей вытянуть 4 туза:
    4С4 = 4!/4!*(4-4)! = 1
    
69184+6768+192+1 = 76145

# %% [markdown]
# Задача 2
#
# Семь человек рассаживаются наудачу на скамейке. Какова вероятность того, что рядом будут сидеть:
#     а) два определённых человека? б) три определённых человека?

# %%
а) Размещения 2х из семи: 7A2 = 7!/(7-2)! = 42
    общее число перестановок 7!
    р = 7A2/7! = 1/(7-2)! ~ 0.008
    
б) 7А3 = 7!/(7-3)! = 210
    р = 7A3/7! = 1/(7-3)! ~ 0.042

# %% [markdown]
# Задача 3
#
# Из 60 вопросов, входящих в экзаменационные билеты, студент знает 50. Какова вероятность того,
# что среди трёх наугад выбранных вопросов студент знает: а) все? б) два?

# %%
Вероятность, что знает 1 билет = 50/60
Вероятность, что не знает 1 билет = 10/60
а) 50/60*49/59*48/58 ~ 0.57
б) 50/60*49/59*10/58 + 50/60*10/59*49/58 + 10/60*50/59*49/58 ~ 0.36

# %% [markdown]
# Задача 4
#
# Бросается игральная кость. Пусть событие A - появление чётного числа,
# событие B - появление числа больше трёх. Являются ли эти события независимыми?

# %%
Зависимы. P(A) = 1/2, P(B) = 1/2

# %% [markdown]
# Задача 5
#
# Допустим, имеется некоторая очень редкая болезнь (поражает 0.1% населения).
# Вы приходите к врачу, вам делают тест на эту болезнь, и тест оказывается положительным.
# Врач говорит вам, что этот тест верно выявляет 99% больных этой болезнью и
# всего лишь в 1% случаев даёт ложный положительный ответ.
#
# Вопрос: какова вероятность, что вы действительно больны ей?

# %%
(0.99*0.001)/(0.99*0.001 + 0.01*0.999)
# Out:
# 0.09016393442622951
