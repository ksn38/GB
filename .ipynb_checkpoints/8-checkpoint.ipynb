# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

SP = pd.read_csv('SnP500.csv').dropna()
RU = pd.read_csv('RUT.csv').dropna()
TR = pd.read_csv('TREAST.csv')
VI = pd.read_csv('VIX.csv')

# %%
len(SP)
# Out:
# 5053

# %%
SP = SP[SP.Date > '2000-12-31']
SP['med'] = (SP.Open + SP.Close)/2

# %%
plt.plot(SP.High - SP.Low)
plt.show()
p = ((SP.High - SP.Low)/SP.med)
plt.plot(p)
plt.show()
pm = ((SP.High - SP.Low)/SP.med)**(1/3)
plt.plot(pm)
plt.show()

# %%
SP.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  4980.000000  4980.000000  4980.000000  4980.000000  4980.000000
# mean   1638.568072  1650.103669  1626.510291  1639.306889  1639.306889
# std     655.292954   658.520350   652.301876   656.086348   656.086348
# min     674.750000   694.750000   665.750000   676.000000   676.000000
# 25%    1146.937500  1158.437500  1137.750000  1148.187500  1148.187500
# 50%    1359.875000  1370.500000  1350.375000  1359.750000  1359.750000
# 75%    2073.000000  2082.500000  2060.562500  2074.250000  2074.250000
# max    3391.750000  3397.500000  3382.000000  3387.750000  3387.750000
#
#              Volume          med
# count  4.980000e+03  4980.000000
# mean   1.369870e+06  1638.937481
# std    8.482371e+05   655.615776
# min    0.000000e+00   682.375000
# 25%    7.247290e+05  1146.687500
# 50%    1.284896e+06  1359.750000
# 75%    1.844430e+06  2072.312500
# max    6.659472e+06  3385.000000

# %%
pm.reset_index(drop=True).head(20)
pm.describe()
# Out:
# count    4980.000000
# mean        0.236917
# std         0.052855
# min         0.092619
# 25%         0.200006
# 50%         0.229823
# 75%         0.264955
# max         0.506739
# dtype: float64

# %%
win = 200

x0 = np.linspace(0, win, win)

for i in range(0, len(p), 5):
    arr = []
    arr.append(pm[i:i+win])
    fig, ax = plt.subplots(nrows=2, ncols=1)
    fig.set_size_inches(10, 10)
    fig.subplots_adjust(wspace=0.3)
    fig.subplots_adjust(hspace=0.3)
    ax1, ax2 = ax.flatten()
    ax1.hist(arr, bins=15)
    ax1.set_xlim([0.05, 0.55])
    ax1.set_ylim([0, 50])
    ax2.plot(SP.med, color='g')
    ax2.plot(SP.med[i:i+win], color='r')
    ax2.set_ylim([600, 3500])
    ax2.set_xlim([0, 6100])
    plt.title(f'{SP.Date[SP.index[i]]}')
    plt.savefig(f'E:/Temp/hist/{SP.Date[SP.index[i]]}.png')
    plt.clf()
    #plt.show()
# Out:
# c:\python37\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
SP.med[3:3+win]
# Out:
# 94     1324.875
# 96     1308.875
# 97     1310.375
# 98     1318.250
# 99     1330.375
#          ...
# 339    1074.750
# 340    1073.125
# 342    1083.000
# 343    1090.625
# 344    1086.000
# Name: med, Length: 200, dtype: float64

# %%
SP.Date[SP.index[1]]
# Out:
# '2001-01-03'

# %%
med = med.reset_index(drop=True)
med
# Out:
# 0       1313.000
# 1       1328.000
# 2       1353.500
# 3       1341.500
# 4       1300.000
#           ...
# 4975    3275.125
# 4976    3285.750
# 4977    3307.625
# 4978    3323.000
# 4979    3335.000
# Length: 4980, dtype: float64

# %%
from datetime import datetime 

datetime.strptime(SP.Date[SP.index[1]], '%Y-%m-%d')

SPV = pd.DataFrame(SP[['Date', 'Volume']])
SPV = SPV.set_index('Date')

TRV = TR.set_index('DATE')

# %%
SPVTRV = SPV[SPV.index > '2002-12-17'].join(TRV)
SPVTRV.TREAST = SPVTRV.TREAST.fillna(method='ffill')
corr = SPVTRV.Volume.rolling(window=100).corr(SPVTRV.TREAST)
plt.plot(corr)
plt.show()

# %%
SPM = SP[['Date', 'med']]
SPM = SPM.set_index('Date')
SPMTRV = SPM[SPM.index > '2002-12-17'].join(TRV)
SPMTRV.TREAST = SPMTRV.TREAST.fillna(method='ffill')
corr = SPMTRV.med.rolling(window=100).corr(SPMTRV.TREAST)
plt.plot(corr)
plt.show()

# %%
corr = SPMTRV.med.rolling(window=100).mean().rolling(window=100).corr(SPMTRV.TREAST)
corr.plot()

# %%
SPMTRV.med.rolling(window=100).mean().plot()
SPMTRV.TREAST.plot(secondary_y=True)
plt.show()

# %%
RU = RU[RU.Date > '2000-12-31']
RU['medr'] = (RU.Open + RU.Close)/2
SPM = SP[['Date', 'med']]
RUM = RU[['Date', 'medr']]
SPM = SPM.set_index('Date')
RUM = RUM.set_index('Date')
SPMRUM = SPM.join(RUM)
SPMRUM.medr = SPMRUM.medr.fillna(method='ffill')

# %%
corr = SPMRUM.med.rolling(window=200).corr(SPMRUM.medr)
plt.plot(corr)
plt.show()

# %%
SPMRUM.med.rolling(window=100).mean().plot()
SPMRUM.medr.rolling(window=100).mean().plot(secondary_y=True)
plt.show()

# %%
corr = SPMTRV.med.rolling(window=100).mean().rolling(window=100).corr(SPMTRV.TREAST)
corr.plot()
